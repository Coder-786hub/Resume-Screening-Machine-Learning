# %% [markdown]
# Import Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# Import clean Dataset

# %%
clean_df = pd.read_csv("clean_resume_data.csv")

# %%
clean_df.head()
# Out:
#          ID Category                                            Feature
# 0  16852973       HR  hr administrator marketing associate hr admini...
# 1  22323967       HR  hr specialist hr operations summary media prof...
# 2  33176873       HR  hr director summary years experience recruitin...
# 3  27018550       HR  hr specialist summary dedicated driven dynamic...
# 4  17812897       HR  hr manager skill highlights hr skills hr depar...

# %% [markdown]
# Exploratory Data Analysis

# %%
plt.figure(figsize = (15,5))
sns.countplot(clean_df["Category"])
plt.xticks(rotation = 90)
plt.show()

# %%
counts = clean_df["Category"].value_counts()
labels = clean_df["Category"].unique()
plt.figure(figsize = (15,10))
plt.pie(counts,labels = labels, autopct = "%1.1f%%", shadow = True, colors = plt.cm.plasma(np.linspace(0,1,3)))
plt.show()

# %% [markdown]
# Balanced Datasets

# %%
from sklearn.utils import resample

# Define the maximum count among all categories
max_count = clean_df["Category"].value_counts().max()

# Resample each category to match the maximum count 
balanced_data = []
for category in clean_df["Category"].unique():
    category_data = clean_df[clean_df["Category"] == category]
    if len(category_data) < max_count:
        #  perform oversampling for categories with fever samples
        balanced_category_data = resample(category_data, replace = True, n_samples = max_count, random_state = 42)
    else:
        # perform undersampling for categories with more samples
        balanced_category_data = resample(category_data, replace = True, n_samples = max_count, random_state = 42)
    balanced_data.append(balanced_category_data)

# Concatenate the balanced data for all categories
balanced_df = pd.concat(balanced_data)

# %%
balanced_df["Category"].value_counts()
# Out:
# Category
# HR                        120
# DESIGNER                  120
# ARTS                      120
# BANKING                   120
# PUBLIC-RELATIONS          120
# CONSTRUCTION              120
# ACCOUNTANT                120
# ENGINEERING               120
# APPAREL                   120
# FINANCE                   120
# CHEF                      120
# AUTOMOBILE                120
# DIGITAL-MEDIA             120
# CONSULTANT                120
# SALES                     120
# BPO                       120
# AGRICULTURE               120
# FITNESS                   120
# HEALTHCARE                120
# BUSINESS-DEVELOPMENT      120
# ADVOCATE                  120
# TEACHER                   120
# INFORMATION-TECHNOLOGY    120
# AVIATION                  120
# Name: count, dtype: int64

# %% [markdown]
# Train-Test-Split

# %%
balanced_df.isnull().sum()
# balanced_df.dropna(inplace = True)
# Out:
# ID          0
# Category    0
# Feature     0
# dtype: int64

# %%
x = balanced_df["Feature"]
y = balanced_df["Category"]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %% [markdown]
# Encoding( TF-IDF)

# %%
tfidf_vectorizer = TfidfVectorizer()
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

# %% [markdown]
# Train Random Forest Classifier

# %%
rf_classifier =RandomForestClassifier()
rf_classifier.fit(x_train_tfidf,y_train)

# step 4.: Accuracy Evaluation
y_pred = rf_classifier.predict(x_test_tfidf)
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy", accuracy)
# Out:
# Accuracy 0.875

# %%
print(classification_report(y_test,y_pred))
# Out:
#                         precision    recall  f1-score   support
#
#             ACCOUNTANT       0.90      0.95      0.93        20
#               ADVOCATE       0.92      0.79      0.85        29
#            AGRICULTURE       0.88      0.91      0.89        23
#                APPAREL       0.82      0.82      0.82        22
#                   ARTS       1.00      0.76      0.86        21
#             AUTOMOBILE       0.95      0.95      0.95        19
#               AVIATION       0.90      0.93      0.91        28
#                BANKING       0.95      0.91      0.93        22
#                    BPO       1.00      1.00      1.00        15
#   BUSINESS-DEVELOPMENT       0.74      0.78      0.76        18
#                   CHEF       0.84      0.93      0.88        28
#           CONSTRUCTION       0.90      1.00      0.95        28
#             CONSULTANT       0.86      0.58      0.69        31
#               DESIGNER       0.96      0.93      0.95        28
#          DIGITAL-MEDIA       0.95      0.86      0.90        21
#            ENGINEERING       0.77      0.87      0.82        23
#                FINANCE       0.94      0.85      0.89        20
#                FITNESS       0.91      0.87      0.89        23
#             HEALTHCARE       0.96      0.82      0.88        28
#                     HR       0.73      0.90      0.81        21
# INFORMATION-TECHNOLOGY       0.69      0.96      0.80        23
#       PUBLIC-RELATIONS       0.91      0.84      0.88        25
#                  SALES       0.82      0.85      0.84        27
#                TEACHER       0.89      1.00      0.94        33
#
#               accuracy                           0.88       576
#              macro avg       0.88      0.88      0.88       576
#           weighted avg       0.88      0.88      0.87       576

# %%
# Confusion Matrics
conf_metrix = confusion_matrix(y_test,y_pred)
plt.figure(figsize = (10,8))
sns.heatmap(conf_metrix, annot = True, fmt = "d", cmap = "Blues", xticklabels = rf_classifier.classes_, yticklabels = rf_classifier.classes_)
plt.xlabel("Predected")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Predictive System

# %%
import re

def cleanResume(txt):
    cleanText = re.sub(r"http\s+", " ", txt)  # raw string for regex
    cleanText = re.sub(r"RT|cc", " ", cleanText)
    cleanText = re.sub(r"#\s+", " ", cleanText)
    cleanText = re.sub(r"@\s+", " ", cleanText)
    # Use raw string to avoid escape sequence issues
    cleanText = re.sub(r"[%s]" % re.escape(r"""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), " ", cleanText)
    cleanText = re.sub(r"[^\x00-\x7f]", " ", cleanText)
    cleanText = re.sub(r"\s+", " ", cleanText)
    return cleanText


# Predection Function
def predict_category(resume_text):
    resume_text = cleanResume(resume_text)
    resume_tfidf = tfidf_vectorizer.transform([resume_text])
    predicted_category = rf_classifier.predict(resume_tfidf)[0]
    return predicted_category

# %%
resume_file = """hr assistant summary highly motivated dynamic human resources professional diverse credentials seeking position growing organization make positive impact company policies experience career growth accomplished human resources administrative professional years experience attentive detail able take initiative prioritize multiple tasks manage workload resourceful team player attitude results driven strong communication analytical interpersonal skills maintain utmost confidentiality highlights compensation knowledge ms office suite ar ap proficiency oracle knowledge great communication skills great analytical skills new hire training filing records management spreadsheets reports office management customer service quickbooks peachtree new hire paperwork experience current company name city state sourced recruited call center departments company responsible finding right candidates matching temporary permanent job placement company maintaining computer system updating entering data brassring responsible complete boarding exit interview paperwork compiling reports spreadsheets order keep track drug test background checks completed boarding process complete initial phone interviews evaluate applicants qualifications scheduling job interviews field managers seeing applicant meet job requirements administer manage scores tests given applicants making job offer help organize job fair manage files applicants qualified circle k naples fl provides convenient services community hr assistant maintained employee compensation benefits pto timecards promotion opportunities explained held trainings new existing employees benefit programs company rules regulations managed background checks ordering paperwork documenting results system requested completed spreadsheet drug tests results managed internal human resources records two stores oversaw investigations disciplinary actions completed exit interview paperwork managed processed time card payroll processing manager timely manner processed new hire paperwork completed boarding process managed records involved hiring process coordinating job posting website reviewing resumes performing telephone interviews reference checks developed strong communication customer service skills result working clients ar ap representative company name city state leading orthopedic medical device company processed invoices credit memos accurate timely manner review documents product returns loaner fees solveed incorrect billing back cash applications made collection calls clients periodically lien waiver nto processed invoice payment cycle insured venders paid timely manner reconciliation vendors managed vendor supplier relations oversaw timely accurate processing invoices purchase orders expense reports credit memos payment transactions office assistant company name city stateelectrical company updated database customer calls worked vender helped reconciliation ledger balanced transmitted daily revenue ar ap filling lien waiver managed collection coordinated complex travel schedules accommodations trip logistics candidates entered personnel subcontractor data central database evaluated timecards accuracy regular overtime hours education associates science human resources organizational leadership rasmussen college city state human resources organizational leadership administration leadership communications profession accounting employment laws human resources organizational development member society human resource management shrm phr certificate graduation volunteer work mentor kids young adults succeed school career path score seminar human resources hire smart rasmussen college skills accounting adp analytical skills ap ar benefits billing call center great communication skills interpersonal skills credit clients customer service customer service skills database detail oriented employee relations expense reports filling filing hiring human resource management human resources human resources processing invoices leadership ledger logistics mentor ms office suite office management organizational development payroll processing peachtree personnel promotion quickbooks recruitment scheduling spreadsheets spreadsheet telephone phone website"""

predicted_category = predict_category(resume_file)
print("Predicted Category", predicted_category)
# Out:
# Predicted Category HR

# %%
resume_file = """37058472	DESIGNER	designer summary designer years product design manufacturing exhibit design visual merchandising comprehensive management logistics experience thrives dynamically changing environments highlights design processing expertise proficient autocad adobe photoshop concept development product specifications color material application strong leader proficient furniture systems vendor sourcing knowledgeable quality control standards procurement specialist dedication product quality compliance gmps accomplishments planned directed coordinated assigned manpower efficiently meet production requirements experience designer company name city state design built custom furniture client initial conceptual idea create cad drawings approval create estimate pricing provide finish samples fabrics cuttings approval creates reviews modifies specification documentation including approval drawings supplier drawings specifications responsible correct building finishing product designed completed key projects time budget high level accuracy reviewed production orders schedules delivery dates inventory levels determine product availability established adjusted work procedures meet production schedules supervised production schedules production quality time delivery senior production manager company name city state management production team responsible price quotations custom quotes formations product line also responsible accurate generation order acknowledgment related approval drawings necessary review launch standard product line worked closely r department assisting necessary development new products created reviewed modified specification documentation including approval drawings supplier drawings specifications mas system e shoptec system reviewed maintained pricing formations product line meeting directly owners evaluate value engineering concepts options developed evaluated maintained quality vendors products prepared analysis new designs overall feasibility possible incorporation standard line products responsible oversee supervise team production products verifying proper assembly techniques finishes upholstery development necessary implementation communicated instructed sales assure smooth flow information production process maintained average turn around custom quotes estimates assisted daily questions issues related custom work engineering orders respective department supervisors necessary authorized fulfillment requests repairs orders returns cancellation discounts interacted managers solve discuss issues concerns updates projects deadlines demands project manager company name city state space furniture planning design capabilities strong organizational communication skills creation ff e color materials coordination drawings information disciplines providing design support completion execution design projects space planning details specifications material palettes served single point contact project scheduling changes monitored team progress enforced deadlines drafted action plans led meetings department executives review project status proposed changes defined project deliverables monitored status tasks responsible small maintenance projects viceroy hotel santa monica education associate arts interior furniture design santa monica college city state certified interior designer bachelor laws llb contract universidade candido mendes city state brazil languages fluent portuguese english intermediate spanish skills drafting rendering material board communication skills conceptual design material organizational
"""
predicted_category = predict_category(resume_file)
print("Predicted Category", predicted_category)
# Out:
# Predicted Category DESIGNER

# %%
import joblib
joblib.dump(rf_classifier,"rf_classifier_categorization.joblib")
joblib.dump(tfidf_vectorizer,"tfidf_vectorizer_categorization.joblib")
# Out:
# ['tfidf_vectorizer_categorization.joblib']
